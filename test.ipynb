# %%
# %load_ext autoreload
# %autoreload 2

# %%
from preprocess import MusicHistory

base_dir = 'data/my_spotify_data/Spotify Account Data'

music = MusicHistory(base_dir)
# Out:
# Reading StreamingHistory_music_0.json..
# Reading StreamingHistory_music_1.json..
# Reading StreamingHistory_music_2.json..
# Reading TasteProfile.json..
# Reading YourLibrary.json..
# Reading YourSoundCapsule.json..

# %%
for highlight_obj in music.highlights:
    print(highlight_obj)
# Out:
# {'date': '2026-07-05', 'highlightType': 'ON_REPEAT', 'onRepeatHighlight': {'entity': 'The Color That Your Eyes Changed With the Color of Your Hair', 'streamCount': 8}}
# {'date': '2026-06-28', 'highlightType': 'MILESTONE', 'multiEntityMilestoneHighlight': {'entities': ['The Antlers', 'Radiohead', 'Green Day', 'The Unforgiven II', 'Wake Me up When September Ends', 'The Unforgiven - Remastered 2021', 'Atrophy', 'Thru The Eyes Of Ruby - Remastered 2012', 'Pictures of Me'], 'milestoneListeningSeconds': 148743}}
# {'date': '2026-06-21', 'highlightType': 'STREAKS', 'streaksHighlight': {'entity': 'Bright Eyes', 'dayStreaks': 5}}
# {'date': '2026-06-14', 'highlightType': 'PROPORTION_LISTENING_ENTITY', 'proportionListeningHighlight': {'entity': ':(', 'listeningPercentage': 99.23052718899282}}
# {'date': '2026-06-07', 'highlightType': 'ON_REPEAT', 'onRepeatHighlight': {'entity': 'Gimme Shelter', 'streamCount': 6}}
# ...
