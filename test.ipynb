# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from preprocess import MusicHistory

base_dir = 'data/my_spotify_data/Spotify Account Data'
music = MusicHistory(base_dir)
# Out:
# Reading StreamingHistory_music_0.json..
# Reading StreamingHistory_music_1.json..
# Reading StreamingHistory_music_2.json..
# Reading TasteProfile.json..
# Reading YourLibrary.json..
# Reading YourSoundCapsule.json..
# dict_keys(['stats', 'highlights'])

# %%
stream_hist = music.streaming_history
stream_hist.sort_values(by='endTime', ascending=True)
# stream_hist.endTime.value_counts()
# Out:
#                endTime         artistName  \
# 0     2025-07-11 23:53        The Beatles
# 1     2025-07-12 00:01        The Beatles
# 2     2025-07-12 00:07     Justin Hurwitz
# 3     2025-07-12 00:10     The Raconteurs
# 4     2025-07-12 00:12         The Smiths
# ...                ...                ...
# 2197  2026-07-12 23:41  The Neighbourhood
# 2198  2026-07-12 23:44         Lord Huron
# 2199  2026-07-12 23:48   Ricky Montgomery
# 2200  2026-07-12 23:53         Ed Sheeran
# 2201  2026-07-12 23:57          Tom Odell
#
#                                               trackName  msPlayed  \
# 0                      Ticket To Ride - Remastered 2009    158036
# 1                      Ticket To Ride - Remastered 2009       324
# 2                                           The Landing    331947
# 3                                   Steady, As She Goes    168877
# 4     Please, Please, Please, Let Me Get What I Want...    112706
# ...                                                 ...       ...
# 2197                                    Sweater Weather    240400
# 2198                                   The Night We Met    208227
# 2199                                Line Without a Hook    249587
# 2200                                            Perfect    263400
# 2201                                       Another Love    244360
#
#               endTime_dt
# 0    2025-07-11 23:53:00
# 1    2025-07-12 00:01:00
# 2    2025-07-12 00:07:00
# 3    2025-07-12 00:10:00
# 4    2025-07-12 00:12:00
# ...                  ...
# 2197 2026-07-12 23:41:00
# 2198 2026-07-12 23:44:00
# 2199 2026-07-12 23:48:00
# 2200 2026-07-12 23:53:00
# 2201 2026-07-12 23:57:00
#
# [22202 rows x 5 columns]

# %%
tasteprofiles = music.taste_profile['artistUris']
music.library[music.library.uri.isin(tasteprofiles)]
# Out:
# Empty DataFrame
# Columns: [artist, album, track, uri]
# Index: []

# %%
music.library.sort_values(by='msPlayed', ascending=False)
# Out:
#                               artist  \
# 12830                          Swans
# 12180               System Of A Down
# 14756                The Microphones
# 8169                        Mud Flow
# 4230                  Lorien Testard
# ...                              ...
# 15135        Queens of the Stone Age
# 15819           Grace Cathedral Park
# 15841                          UNKLE
# 16196  Sons of an Illustrious Father
# 16396                      Sigur Rós
#
#                                                    album  \
# 12830                                         To Be Kind
# 12180                                          Mezmerize
# 14756           Little Bird Flies into a Big Black Cloud
# 8169                                          Best Songs
# 4230   Clair Obscur: Expedition 33 (Original Soundtrack)
# ...                                                  ...
# 15135                                  ...Like Clockwork
# 15819                          In the Evenings of Regret
# 15841                                    Psyence Fiction
# 16196                                               Sons
# 16396                                      Ágætis Byrjun
#
#                                      track  \
# 12830  Bring The Sun/Toussaint L'Ouverture
# 12180                          Radio/Video
# 14756                        I Got Stabbed
# 8169           The Sense of Me / Chemicals
# 4230                     Une vie à t'aimer
# ...                                    ...
# 15135       The Vampyre of Time And Memory
# 15819    It's All Well Above Wonder Anyway
# 15841            Rabbit In Your Headlights
# 16196                     Very Few Dancers
# 16396                       Hjartað hamast
#
#                                         uri           endTime   msPlayed  \
# 12830  spotify:track:6QXQEeKlpcEtg5eOJfr8nO  2026-01-15 21:38  1716436.0
# 12180  spotify:track:41pOIT2t1rvr2Trg1HQChZ  2025-10-29 21:04  1456174.0
# 14756  spotify:track:0ANQU0FbcFqk3Fdk0v4pU1  2025-11-26 01:47  1449843.0
# 8169   spotify:track:0bhezzuZS8QPoVwZppyXgn  2026-01-31 23:56  1378897.0
# 4230   spotify:track:4QEXM9na0mWIIt5Hwbsges  2025-07-20 22:49  1224527.0
# ...                                     ...               ...        ...
# 15135  spotify:track:5q453TyHMg7pxYdNG9nufn               NaN        NaN
# 15819  spotify:track:4AhSvS8COVUa2BplVN85Jh               NaN        NaN
# 15841  spotify:track:4z11Etf60lVE01ki1avHuD               NaN        NaN
# 16196  spotify:track:20Ywpk7eIYByt8g7qyv9Kz               NaN        NaN
# 16396  spotify:track:7a3KAxwAi2JXrrCvSfmkwT               NaN        NaN
#
#                endTime_dt
# 12830 2026-01-15 21:38:00
# 12180 2025-10-29 21:04:00
# 14756 2025-11-26 01:47:00
# 8169  2026-01-31 23:56:00
# 4230  2025-07-20 22:49:00
# ...                   ...
# 15135                 NaT
# 15819                 NaT
# 15841                 NaT
# 16196                 NaT
# 16396                 NaT
#
# [16413 rows x 7 columns]

# %%
music.library.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16413 entries, 0 to 16412
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   artist      16413 non-null  object
#  1   album       16413 non-null  object
#  2   track       16413 non-null  object
#  3   uri         16413 non-null  object
#  4   endTime     16291 non-null  object
#  5   artistName  16291 non-null  object
#  6   trackName   16291 non-null  object
#  7   msPlayed    16291 non-null  float64
#  8   endTime_dt  16291 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 1.1+ MB

# %%
music.highlights
# Out:
# [{'date': '2026-07-05',
#   'highlightType': 'ON_REPEAT',
#   'onRepeatHighlight': {'entity': 'The Color That Your Eyes Changed With the Color of Your Hair',
#    'streamCount': 8}},
#  {'date': '2026-06-28',
#   'highlightType': 'MILESTONE',
#   'multiEntityMilestoneHighlight': {'entities': ['The Antlers',
#     'Radiohead',
#     'Green Day',
#     'The Unforgiven II',
#     'Wake Me up When September Ends',
#     'The Unforgiven - Remastered 2021',
#     'Atrophy',
#     'Thru The Eyes Of Ruby - Remastered 2012',
#     'Pictures of Me'],
#    'milestoneListeningSeconds': 148743}},
#  {'date': '2026-06-21',
#   'highlightType': 'STREAKS',
#   'streaksHighlight': {'entity': 'Bright Eyes', 'dayStreaks': 5}},
#  {'date': '2026-06-14',
#   'highlightType': 'PROPORTION_LISTENING_ENTITY',
#   'proportionListeningHighlight': {'entity': ':(',
#    'listeningPercentage': 99.23052718899282}},
#  {'date': '2026-06-07',
#   'highlightType': 'ON_REPEAT',
#   'onRepeatHighlight': {'entity': 'Gimme Shelter', 'streamCount': 6}},
#  {'date': '2026-05-31',
#   'highlightType': 'UNLIKE_COMBINATION',
#   'unlikeCombinationHighlight': {'firstEntity': 'Moth To A Flame (with The Weeknd)',
#    'secondEntity': 'The Hurricane'}},
#  {'date': '2026-05-24',
#   'highlightType': 'MILESTONE',
#   'milestoneHighlight': {'entity': ':(', 'milestoneListeningSeconds': 103812}},
#  {'date': '2026-05-17',
#   'highlightType': 'YOU_STAND_OUT',
#   'youStandOutHighlight': {'entity': 'Radiohead',
#    'country': 'US',
#    'secondsPlayed': 7674,
#    'marketAvgSecondsPlayed': 858.5097}},
#  {'date': '2026-05-10',
#   'highlightType': 'PROPORTION_LISTENING_ENTITY',
#   'proportionListeningHighlight': {'entity': 'Metallica',
#    'listeningPercentage': 36.03213056228484}},
#  {'date': '2026-05-03',
#   'highlightType': 'STREAKS',
#   'streaksHighlight': {'entity': 'Sufjan Stevens', 'dayStreaks': 7}},
#  {'date': '2026-04-26',
#   'highlightType': 'STREAKS',
#   'streaksHighlight': {'entity': 'System Of A Down', 'dayStreaks': 5}},
#  {'date': '2026-04-19',
#   'highlightType': 'ON_REPEAT',
#   'onRepeatHighlight': {'entity': 'Myth', 'streamCount': 8}},
#  {'date': '2026-04-12',
#   'highlightType': 'STREAKS',
#   'streaksHighlight': {'entity': 'The Antlers', 'dayStreaks': 7}},
#  {'date': '2026-04-05',
#   'highlightType': 'MILESTONE',
#   'multiEntityMilestoneHighlight': {'entities': ['The Antlers',
#     'Radiohead',
#     'Beach House',
#     'Man of War',
#     'Gimme Shelter',
#     'No One Is Ever Going to Want Me',
#     'Degausser',
#     'Atrophy',
#     'Armchairs'],
#    'milestoneListeningSeconds': 105950}},
#  {'date': '2026-03-29',
#   'highlightType': 'PROPORTION_LISTENING_ENTITY',
#   'proportionListeningHighlight': {'entity': 'The Rolling Stones',
#    'listeningPercentage': 47.5095959825831}},
#  {'date': '2026-03-22',
#   'highlightType': 'ON_REPEAT',
#   'onRepeatHighlight': {'entity': 'Pictures of Me', 'streamCount': 20}},
#  {'date': '2026-03-15',
#   'highlightType': 'STREAKS',
#   'streaksHighlight': {'entity': 'Queens of the Stone Age', 'dayStreaks': 7}},
#  {'date': '2026-03-08',
#   'highlightType': 'YOU_STAND_OUT',
#   'youStandOutHighlight': {'entity': 'Radiohead',
#    'country': 'US',
#    'secondsPlayed': 4878,
#    'marketAvgSecondsPlayed': 902.6665}},
#  {'date': '2026-03-01',
#   'highlightType': 'MILESTONE',
#   'milestoneHighlight': {'entity': 'Silver Mt. Zion',
#    'milestoneListeningSeconds': 43163}},
#  {'date': '2026-02-22',
#   'highlightType': 'PROPORTION_LISTENING_ENTITY',
#   'proportionListeningHighlight': {'entity': ':(',
#    'listeningPercentage': 44.86451612903225}},
#  {'date': '2026-02-15',
#   'highlightType': 'ON_REPEAT',
#   'onRepeatHighlight': {'entity': 'Plush', 'streamCount': 9}},
#  {'date': '2026-02-08',
#   'highlightType': 'MILESTONE',
#   'multiEntityMilestoneHighlight': {'entities': ['The Antlers',
#     'Queens of the Stone Age',
#     'The Smiths',
#     'Murder And Crime',
#     'Chemicals',
#     'Lazy Eyelids',
#     'Myth',
#     'Farewell to All These Rotten Teeth',
#     'Armchairs'],
#    'milestoneListeningSeconds': 136712}},
#  {'date': '2026-02-01',
#   'highlightType': 'STREAKS',
#   'streaksHighlight': {'entity': 'Until The End', 'dayStreaks': 3}},
#  {'date': '2026-01-25',
#   'highlightType': 'YOU_STAND_OUT',
#   'youStandOutHighlight': {'entity': 'Deftones',
#    'country': 'US',
#    'secondsPlayed': 4868,
#    'marketAvgSecondsPlayed': 1263.9349}},
#  {'date': '2026-01-18',
#   'highlightType': 'ON_REPEAT',
#   'onRepeatHighlight': {'entity': 'The Piano Song', 'streamCount': 10}},
#  {'date': '2026-01-11',
#   'highlightType': 'MILESTONE',
#   'milestoneHighlight': {'entity': ':(', 'milestoneListeningSeconds': 38090}},
#  {'date': '2026-01-04',
#   'highlightType': 'PROPORTION_LISTENING_ENTITY',
#   'proportionListeningHighlight': {'entity': ':(',
#    'listeningPercentage': 62.3625311286755}},
#  {'date': '2025-12-28',
#   'highlightType': 'STREAKS',
#   'streaksHighlight': {'entity': 'Is There Anybody Here?', 'dayStreaks': 3}}]
